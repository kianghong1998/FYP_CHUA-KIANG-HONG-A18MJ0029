# %%
#Import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from sklearn import model_selection
print(tf.__version__)
# Out:
# 2.8.0

# %%
#Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read excel file that contain data
data = pd.read_excel ('/content/drive/MyDrive/FYP/new version/Setapak.xlsx', sheet_name='Sheet1')
# Skip data on 6am and 6pm
data = data[0::2]
# Set the index of the DataFrame to weather type
data = data.set_index("Weather")
data.head()
# Out:
#                      Date      Time  Barometer  Highest Temperature  \
# Weather
# Passing clouds 2021-01-01  00:00:00     1010.0                 26.0
# Passing clouds 2021-01-01  12:00:00     1009.0                 31.0
# Passing clouds 2021-01-02  00:00:00     1010.0                 26.0
# Passing clouds 2021-01-02  12:00:00     1009.0                 29.0
# Light rain     2021-01-03  00:00:00     1010.0                 25.0
#
#                 Lowest temperature  Average Temperature  Humidity  Wind Speed
# Weather
# Passing clouds                25.0                 25.5      90.0         1.0
# Passing clouds                27.0                 29.0      64.0         5.0
# Passing clouds                25.0                 25.5      90.0         3.0
# Passing clouds                28.0                 28.5      73.0         6.0
# Light rain                    24.0                 24.5      94.0         5.0

# %%
# Drop data during thunderstorms and raining days
data = data.drop(["Light rain", "Thunderstorms"])
data.head()
# Out:
#                      Date      Time  Barometer  Highest Temperature  \
# Weather
# Passing clouds 2021-01-01  00:00:00     1010.0                 26.0
# Passing clouds 2021-01-01  12:00:00     1009.0                 31.0
# Passing clouds 2021-01-02  00:00:00     1010.0                 26.0
# Passing clouds 2021-01-02  12:00:00     1009.0                 29.0
# Passing clouds 2021-01-04  12:00:00     1009.0                 30.0
#
#                 Lowest temperature  Average Temperature  Humidity  Wind Speed
# Weather
# Passing clouds                25.0                 25.5      90.0         1.0
# Passing clouds                27.0                 29.0      64.0         5.0
# Passing clouds                25.0                 25.5      90.0         3.0
# Passing clouds                28.0                 28.5      73.0         6.0
# Passing clouds                27.0                 28.5      68.0         7.0

# %%
# Remove data's index
data = data.reset_index()

# Remove wrong data by removing data row with wind speed lower than 0
# Clean data by removing data row with wind speed higher than 15
for i in data.index:
  if ((data.loc[i, "Wind Speed"]<0)):
    data.drop(i, inplace = True)

for i in data.index:
  if ((data.loc[i, "Wind Speed"]>15)):
    data.drop(i, inplace = True)

data.describe()
# Out:
#          Barometer  Highest Temperature  Lowest temperature  \
# count   801.000000           801.000000          801.000000
# mean   1009.439451            29.600499           26.972534
# std       1.467699             3.375678            2.625689
# min    1005.000000            24.000000           22.000000
# 25%    1008.000000            27.000000           25.000000
# 50%    1010.000000            29.000000           26.000000
# 75%    1010.000000            33.000000           29.000000
# max    1017.000000            36.000000           33.000000
#
#        Average Temperature    Humidity  Wind Speed
# count           801.000000  801.000000  801.000000
# mean             28.286517   75.312110    5.946317
# std               2.838352   14.418823    4.077176
# min              23.500000   40.000000    0.000000
# 25%              25.500000   62.000000    2.000000
# 50%              27.500000   79.000000    5.000000
# 75%              31.000000   88.000000   10.000000
# max              34.000000   98.000000   15.000000

# %%
# Plot relationship between data
sns.pairplot(data[['Average Temperature', 'Humidity', 'Wind Speed' ]], diag_kind='kde')

# %%
x = data.iloc[:, 6:8]
y = data.iloc[:, 8]

# %%
x
# Out:
#      Average Temperature  Humidity
# 0                   25.5      90.0
# 1                   29.0      64.0
# 2                   25.5      90.0
# 3                   28.5      73.0
# 4                   28.5      68.0
# ..                   ...       ...
# 814                 24.0      95.0
# 815                 25.0      94.0
# 816                 29.0      76.0
# 817                 25.0      92.0
# 818                 32.0      58.0
#
# [801 rows x 2 columns]

# %%
y
# Out:
# 0      1.0
# 1      5.0
# 2      3.0
# 3      6.0
# 4      7.0
#       ...
# 814    0.0
# 815    2.0
# 816    6.0
# 817    1.0
# 818    9.0
# Name: Wind Speed, Length: 801, dtype: float64

# %%
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense
from keras.layers import GRU
from keras.metrics import Accuracy
from sklearn.preprocessing import StandardScaler

model = Sequential()
model.add(Dense(1, input_dim=2, activation='linear'))
model.compile(loss='mse', optimizer='rmsprop')

print(model.summary())
history = model.fit(x,y, epochs=150, batch_size=3)

# list all data in history
print(history.history.keys())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/150
# 267/267 [==============================] - 1s 1ms/step - loss: 508.9948
# Epoch 2/150
# 267/267 [==============================] - 0s 1ms/step - loss: 83.6149
# Epoch 3/150
# 267/267 [==============================] - 0s 1ms/step - loss: 64.5091
# Epoch 4/150
# 267/267 [==============================] - 0s 1ms/step - loss: 54.5674
# Epoch 5/150
# 267/267 [==============================] - 0s 1ms/step - loss: 45.3280
# Epoch 6/150
# 267/267 [==============================] - 0s 1ms/step - loss: 37.4527
# Epoch 7/150
# 267/267 [==============================] - 0s 1ms/step - loss: 30.4408
# Epoch 8/150
# 267/267 [==============================] - 0s 1ms/step - loss: 24.5715
# Epoch 9/150
# 267/267 [==============================] - 0s 1ms/step - loss: 19.3826
# Epoch 10/150
# 267/267 [==============================] - 0s 1ms/step - loss: 15.2138
# Epoch 11/150
# 267/267 [==============================] - 0s 1ms/step - loss: 11.7890
# Epoch 12/150
# 267/267 [==============================] - 0s 1ms/step - loss: 8.9941
# Epoch 13/150
# 267/267 [==============================] - 0s 1ms/step - loss: 6.9904
# Epoch 14/150
# 267/267 [==============================] - 0s 1ms/step - loss: 5.7752
# Epoch 15/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.9722
# Epoch 16/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.5246
# Epoch 17/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.2962
# Epoch 18/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.1646
# Epoch 19/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0821
# Epoch 20/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0702
# Epoch 21/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0034
# Epoch 22/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0106
# Epoch 23/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0169
# Epoch 24/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9966
# Epoch 25/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0074
# Epoch 26/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0346
# Epoch 27/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0220
# Epoch 28/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0190
# Epoch 29/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0196
# Epoch 30/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0145
# Epoch 31/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0109
# Epoch 32/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0035
# Epoch 33/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0056
# Epoch 34/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0174
# Epoch 35/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0048
# Epoch 36/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0077
# Epoch 37/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9905
# Epoch 38/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0240
# Epoch 39/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9878
# Epoch 40/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0124
# Epoch 41/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0054
# Epoch 42/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0291
# Epoch 43/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9748
# Epoch 44/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0126
# Epoch 45/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9966
# Epoch 46/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0066
# Epoch 47/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0171
# Epoch 48/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0150
# Epoch 49/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0267
# Epoch 50/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0345
# Epoch 51/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9807
# Epoch 52/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0140
# Epoch 53/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0375
# Epoch 54/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9794
# Epoch 55/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0420
# Epoch 56/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0293
# Epoch 57/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0215
# Epoch 58/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0383
# Epoch 59/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0051
# Epoch 60/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0061
# Epoch 61/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9942
# Epoch 62/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0067
# Epoch 63/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9713
# Epoch 64/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0246
# Epoch 65/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0225
# Epoch 66/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0261
# Epoch 67/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0211
# Epoch 68/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0324
# Epoch 69/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0184
# Epoch 70/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0081
# Epoch 71/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0010
# Epoch 72/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0079
# Epoch 73/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0253
# Epoch 74/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0141
# Epoch 75/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0254
# Epoch 76/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9884
# Epoch 77/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0172
# Epoch 78/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9979
# Epoch 79/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0134
# Epoch 80/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9837
# Epoch 81/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9856
# Epoch 82/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0012
# Epoch 83/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9946
# Epoch 84/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0203
# Epoch 85/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0169
# Epoch 86/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0221
# Epoch 87/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0151
# Epoch 88/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9833
# Epoch 89/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0277
# Epoch 90/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0177
# Epoch 91/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9794
# Epoch 92/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0310
# Epoch 93/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0007
# Epoch 94/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0023
# Epoch 95/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9975
# Epoch 96/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0268
# Epoch 97/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0172
# Epoch 98/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9989
# Epoch 99/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0129
# Epoch 100/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0198
# Epoch 101/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0272
# Epoch 102/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0142
# Epoch 103/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0186
# Epoch 104/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9998
# Epoch 105/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0150
# Epoch 106/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0280
# Epoch 107/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9738
# Epoch 108/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0075
# Epoch 109/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9999
# Epoch 110/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9952
# Epoch 111/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0206
# Epoch 112/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0247
# Epoch 113/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0159
# Epoch 114/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0031
# Epoch 115/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0077
# Epoch 116/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0153
# Epoch 117/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0454
# Epoch 118/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9964
# Epoch 119/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0178
# Epoch 120/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0255
# Epoch 121/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0074
# Epoch 122/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0304
# Epoch 123/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0117
# Epoch 124/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9980
# Epoch 125/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9854
# Epoch 126/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0156
# Epoch 127/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0003
# Epoch 128/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0157
# Epoch 129/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0061
# Epoch 130/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0154
# Epoch 131/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9888
# Epoch 132/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9939
# Epoch 133/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0062
# Epoch 134/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0216
# Epoch 135/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0249
# Epoch 136/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0220
# Epoch 137/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0188
# Epoch 138/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0027
# Epoch 139/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0239
# Epoch 140/150
# 267/267 [==============================] - 0s 1ms/step - loss: 3.9920
# Epoch 141/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0046
# Epoch 142/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0029
# Epoch 143/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0146
# Epoch 144/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0117
# Epoch 145/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0093
# Epoch 146/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0111
# Epoch 147/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0089
# Epoch 148/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0233
# Epoch 149/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0134
# Epoch 150/150
# 267/267 [==============================] - 0s 1ms/step - loss: 4.0168
# dict_keys(['loss'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# Show predicted wind speed by model
data['Predicted_WindSpeed'] = model.predict (x)
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
rmse = mean_squared_error(data['Wind Speed'], model.predict (x), squared=False)
mse = mean_squared_error(data['Wind Speed'], model.predict (x))
r_squared=r2_score(data['Wind Speed'], model.predict (x))

print("The model's r2 is ", r_squared*100, "%")
print("Mean squared error is ", mse)
print("Root mean squared error is ", rmse)
data.head(10)
# Out:
# The model's r2 is  76.17377023389184 %
# Mean squared error is  3.9557763107988464
# Root mean squared error is  1.9889133492434623
#           Weather       Date      Time  Barometer  Highest Temperature  \
# 0  Passing clouds 2021-01-01  00:00:00     1010.0                 26.0
# 1  Passing clouds 2021-01-01  12:00:00     1009.0                 31.0
# 2  Passing clouds 2021-01-02  00:00:00     1010.0                 26.0
# 3  Passing clouds 2021-01-02  12:00:00     1009.0                 29.0
# 4  Passing clouds 2021-01-04  12:00:00     1009.0                 30.0
# 5  Passing clouds 2021-01-05  00:00:00     1009.0                 26.0
# 6  Passing clouds 2021-01-05  12:00:00     1008.0                 32.0
# 7  Passing clouds 2021-01-06  00:00:00     1009.0                 26.0
# 8  Passing clouds 2021-01-06  12:00:00     1008.0                 28.0
# 9  Passing clouds 2021-01-07  00:00:00     1009.0                 25.0
#
#    Lowest temperature  Average Temperature  Humidity  Wind Speed  \
# 0                25.0                 25.5      90.0         1.0
# 1                27.0                 29.0      64.0         5.0
# 2                25.0                 25.5      90.0         3.0
# 3                28.0                 28.5      73.0         6.0
# 4                27.0                 28.5      68.0         7.0
# 5                24.0                 25.0      92.0         2.0
# 6                26.0                 29.0      65.0        14.0
# 7                25.0                 25.5      92.0         1.0
# 8                27.0                 27.5      70.0         7.0
# 9                24.0                 24.5      87.0         2.0
#
#    Predicted_WindSpeed
# 0             2.232275
# 1             7.809083
# 2             2.232275
# 3             6.294642
# 4             6.973599
# 5             1.668374
# 6             7.673292
# 7             1.960693
# 8             6.117378
# 9             2.055012

# %%
plt.plot (data['Wind Speed'], label='real')
plt.plot (data['Predicted_WindSpeed'], label='predicted')
plt.legend()
plt.show()

# %%
data.count()
# Out:
# Weather                801
# Date                   801
# Time                   801
# Barometer              801
# Highest Temperature    801
# Lowest temperature     801
# Average Temperature    801
# Humidity               801
# Wind Speed             801
# Predicted_WindSpeed    801
# dtype: int64

# %%
model_output = data ['Predicted_WindSpeed']
from sklearn.linear_model import LinearRegression
coeficient_founder = LinearRegression ()
coeficient_founder.fit (x, model_output)

# Print the coeficients and linar equation of trained model

print("Model coefficient 1:    ", coeficient_founder.coef_[0])
print("Model coefficient 2:    ", coeficient_founder.coef_[1])
print("Model intercept:", coeficient_founder.intercept_)
print ("Model best fit equation: Wind Speed Predicted(km/h)= " + str(coeficient_founder.coef_[0]) + "(Temperature in °C) \
+ (" + str(coeficient_founder.coef_[1]) + ")(Humidity in %) + (" + str(coeficient_founder.intercept_) + ")")
# Out:
# Model coefficient 1:     0.5846378536452073
# Model coefficient 2:     -0.1357914044002198
# Model intercept: -0.4547636585074626
# Model best fit equation: Wind Speed Predicted(km/h)= 0.5846378536452073(Temperature in °C) + (-0.1357914044002198)(Humidity in %) + (-0.4547636585074626)

# %%
#Save excel file with predicted value
data.to_excel(r'/content/drive/MyDrive/FYP/new version/Predict_MLR.xlsx', index = False)

# Save the Tensorflow model
# Needed to be converted to C array before applied on ESP32

import pathlib
export_dir = 'saved_model/'
tf.saved_model.save(model, export_dir)
# Convert the model to an in-memory object
converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)
tflite_model = converter.convert()
# Write to a file
tflite_model_file = pathlib.Path('mlr_model.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: saved_model/assets
# INFO:tensorflow:Assets written to: saved_model/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 904
